# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
# Out:
# UsageError: unrecognized arguments: matplotlib backend: Qt5Agg

# %%
path = Path('C:/Users/fabia/Desktop/stag.csv')
data = np.genfromtxt(path, delimiter=',', skip_header=7)#, skip_footer=100)

# %%
num_ch = data.shape[1] - 1
samples = data[:,0]
time = samples*0.00098394
v = []
i = []
for j in range(num_ch//2):
    v.append(data[:, j*2+1])
    i.append(data[:, j*2+2])
    
# Power
for j in range(num_ch//2):
    plt.figure(figsize=(12,4))
    plt.title('Power channel ' + str(j+1))
    power = v[j]*i[j]
    ylabel = 'Power [W]'
    if(np.mean(power) < 1):
        power = 1000*power
        ylabel = 'Power [mW]'
    plt.plot(time, power)
    #average = np.full(time.shape, np.mean(power))
    #plt.plot(time, average)
    #plt.legend(['Trace', 'Average'])
    plt.xlabel('Time [s]')
    plt.ylabel(ylabel)
    plt.ylim([0, max(power)*1.05])
    plt.grid()
    plt.show()

# Current
for j in range(num_ch//2):
    plt.figure(figsize=(12,4))
    plt.title('Current channel ' + str(j+1))
    current = i[j]
    ylabel = 'Current [A]'
    if(np.mean(current) < 1):
        current = 1000*current
        ylabel = 'Current [mA]'
    plt.plot(time, current)
    #average = np.full(time.shape, np.mean(current))
    #plt.plot(time, average)
    #plt.legend(['Trace', 'Average'])
    plt.xlabel('Time [s]')
    plt.ylabel(ylabel)
    plt.ylim([0, max(current)*1.05])
    plt.grid()
    plt.show()

# %%
plt.figure()
plt.plot(samples[11000:11200], i2[11000:11200])
plt.grid()
plt.show()

# %%
np.mean(i1[0:9000]*v1[0:9000])
# Out:
# 1.0918835918203977

# %%
np.mean(i1[11000:30000]*v1[11000:30000])
# Out:
# 1.0843400499753786

# %%
data.shape
# Out:
# (59698, 5)
